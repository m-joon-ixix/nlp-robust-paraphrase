# %%
from common.pickle_utils import load_from_pickle
from common.const import SUBSETS
from evaluate.run_eval import stats_filepath

for subset in SUBSETS:
    df = load_from_pickle(stats_filepath(subset, "test"))
    display(df)
# Out:
# Loading Data from './output/general-knowledge/stat/original_test.pkl'
#                                  accuracy  xparacon
# Claude-3.5-Sonnet                   0.876     3.428
# Deepseek-R1                         0.850     3.378
# Gemini-2.5-Flash-Lite               0.861     3.339
# Llama-3.1-8B-Instruct               0.781     2.186
# Llama-3.1-8B-Instruct_sft           0.798     2.629
# Llama-3.1-70B-Instruct              0.869     3.219
# Llama-3.1-405B                      0.882     3.272
# Mistral-7B-Instruct-v0.3            0.697     2.663
# Mistral-7B-Instruct-v0.3_sft        0.735     2.854
# Mistral-Small-24B-Instruct-2501     0.855     3.121
# Qwen3-4B-Instruct-2507              0.802     2.848
# Qwen3-4B-Instruct-2507_sft          0.821     2.920
# Qwen3-30B-A3B-Instruct-2507         0.866     3.136
# Loading Data from './output/math-reasoning/stat/original_test.pkl'
#                                  accuracy  xparacon
# Claude-3.5-Sonnet                   0.959     5.164
# Deepseek-R1                         0.915     4.405
# Gemini-2.5-Flash-Lite               0.941     4.915
# Llama-3.1-8B-Instruct               0.738     1.924
# Llama-3.1-8B-Instruct_sft           0.685     2.316
# Llama-3.1-70B-Instruct              0.863     3.114
# Llama-3.1-405B                      0.934     3.762
# Mistral-7B-Instruct-v0.3            0.344     2.728
# Mistral-7B-Instruct-v0.3_sft        0.405     2.617
# Mistral-Small-24B-Instruct-2501     0.899     3.435
# Qwen3-4B-Instruct-2507              0.942     4.489
# Qwen3-4B-Instruct-2507_sft          0.951     4.856
# Qwen3-30B-A3B-Instruct-2507         0.935     4.034
